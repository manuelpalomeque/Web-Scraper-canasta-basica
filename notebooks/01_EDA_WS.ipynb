# %%
# instalar librerias necesarias:
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# Importar librerias necesarias:
import pandas as pd

# %%
# Leer los archivos .csv:

# Hiper Libertad:
df_hiper_libertad_1 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad.csv')
df_hiper_libertad_2 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad1.csv')

# Disco:
df_disco_1 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco.csv')
df_disco_2 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco1.csv')

# %%
# Unirlos por super mercado:
df_hiper_libertad = pd.concat([df_hiper_libertad_1, df_hiper_libertad_2], ignore_index=True)
df_disco = pd.concat([df_disco_1, df_disco_2], ignore_index=True)

# Agregar una columna "supermercado" con el valor correspondiente a cada uno:
df_hiper_libertad['Supermercado'] = 'Hiper Libertad'
df_disco['Supermercado'] = 'Disco'

# %%
# Verificar encabezados:
df_disco.head()
# Out:
#         fecha   hora                            nombre_producto  \
# 0  13-04-2025  13:34           Galletitas Surtido Bagley 400 Gr
# 1  13-04-2025  13:34  Dulce De Leche La Serenisima Clasico 400g
# 2  13-04-2025  13:34               Papa Cepillada Granel Por Kg
# 3  13-04-2025  13:34                    Cebolla Superior Por Kg
# 4  13-04-2025  13:34                   Pollo Fresco Con Menudos
#
#           Precio                                                URL  \
# 0           2117  https://www.disco.com.ar/galletitas-surtido-ba...
# 1           3300  https://www.disco.com.ar/dulce-de-leche-la-ser...
# 2            999  https://www.disco.com.ar/papa-cepillada-granel...
# 3  No disponible  https://www.disco.com.ar/cebolla-superior-por-...
# 4           3399  https://www.disco.com.ar/pollo-fresco-con-menu...
#
#   Nombre Producto Supermercado
# 0             NaN        Disco
# 1             NaN        Disco
# 2             NaN        Disco
# 3             NaN        Disco
# 4             NaN        Disco

# %%
df_hiper_libertad.head()
# Out:
#         fecha   hora                           Nombre Producto   Precio  \
# 0  13-04-2025  12:16                   ARROZ ALA LGO FINO X1KG     1999
# 1  13-04-2025  12:16  GALLETITAS SANDWICH MEDIATARDE X3 107 G.     1529
# 2  13-04-2025  12:16            GALLETAS SURTIDO DIVERSIO 400G     1990
# 3  13-04-2025  12:16             DULCE LECHE ILOLAY FLIARX400G     2350
# 4  13-04-2025  12:16       MANZANA COMERCIAL FRACCIONADA X KG.  2699, 0
#
#                                                  URL    Supermercado
# 0  https://www.hiperlibertad.com.ar/arroz-blanco-...  Hiper Libertad
# 1  https://www.hiperlibertad.com.ar/galletitas-sa...  Hiper Libertad
# 2  https://www.hiperlibertad.com.ar/galletitas-su...  Hiper Libertad
# 3  https://www.hiperlibertad.com.ar/dulce-de-lech...  Hiper Libertad
# 4  https://www.hiperlibertad.com.ar/manzana-roja-...  Hiper Libertad

# %%
# Dataframe final y unificado:
df_unificado = pd.concat([df_disco, df_hiper_libertad], ignore_index=True)
# Out:
#         fecha   hora                            nombre_producto  \
# 0  13-04-2025  13:34           Galletitas Surtido Bagley 400 Gr
# 1  13-04-2025  13:34  Dulce De Leche La Serenisima Clasico 400g
# 2  13-04-2025  13:34               Papa Cepillada Granel Por Kg
# 3  13-04-2025  13:34                    Cebolla Superior Por Kg
# 4  13-04-2025  13:34                   Pollo Fresco Con Menudos
#
#           Precio                                                URL  \
# 0           2117  https://www.disco.com.ar/galletitas-surtido-ba...
# 1           3300  https://www.disco.com.ar/dulce-de-leche-la-ser...
# 2            999  https://www.disco.com.ar/papa-cepillada-granel...
# 3  No disponible  https://www.disco.com.ar/cebolla-superior-por-...
# 4           3399  https://www.disco.com.ar/pollo-fresco-con-menu...
#
#   Nombre Producto Supermercado
# 0             NaN        Disco
# 1             NaN        Disco
# 2             NaN        Disco
# 3             NaN        Disco
# 4             NaN        Disco

# %%
# Previsualizar primeros registros
df_unificado.head()
# Out:
#         fecha   hora                            nombre_producto  \
# 0  13-04-2025  13:34           Galletitas Surtido Bagley 400 Gr
# 1  13-04-2025  13:34  Dulce De Leche La Serenisima Clasico 400g
# 2  13-04-2025  13:34               Papa Cepillada Granel Por Kg
# 3  13-04-2025  13:34                    Cebolla Superior Por Kg
# 4  13-04-2025  13:34                   Pollo Fresco Con Menudos
#
#           Precio                                                URL  \
# 0           2117  https://www.disco.com.ar/galletitas-surtido-ba...
# 1           3300  https://www.disco.com.ar/dulce-de-leche-la-ser...
# 2            999  https://www.disco.com.ar/papa-cepillada-granel...
# 3  No disponible  https://www.disco.com.ar/cebolla-superior-por-...
# 4           3399  https://www.disco.com.ar/pollo-fresco-con-menu...
#
#   Nombre Producto Supermercado
# 0             NaN        Disco
# 1             NaN        Disco
# 2             NaN        Disco
# 3             NaN        Disco
# 4             NaN        Disco

# %%
# informacion general del dataframe
df_unificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            121 non-null    object
#  1   hora             121 non-null    object
#  2   nombre_producto  51 non-null     object
#  3   Precio           121 non-null    object
#  4   URL              121 non-null    object
#  5   Nombre Producto  66 non-null     object
#  6   Supermercado     121 non-null    object
# dtypes: object(7)
# memory usage: 6.7+ KB
