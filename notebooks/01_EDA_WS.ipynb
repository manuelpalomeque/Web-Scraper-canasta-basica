# %% [markdown]
# # Análisis Exploratorio de Datos (EDA - Exploratory Data Analysis)

# %%
# instalar librerias necesarias:
# !pip install pandas

# %%
# Importar librerias necesarias:
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from google.colab import files

# %% [markdown]
# ## 1. Cargar datos:

# %%
# Leer los archivos .csv:

# Hiper Libertad:
df_hiper_libertad_0 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad.csv')
df_hiper_libertad_1 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad1.csv')
df_hiper_libertad_2 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad2.csv')
df_hiper_libertad_3 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad3.csv')
df_hiper_libertad_4 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad4.csv')
df_hiper_libertad_5 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad5.csv')
df_hiper_libertad_6 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad6.csv')
df_hiper_libertad_7 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad7.csv')
df_hiper_libertad_8 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad8.csv')
df_hiper_libertad_9 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad9.csv')
df_hiper_libertad_10 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad10.csv')
df_hiper_libertad_11 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad11.csv')
df_hiper_libertad_12 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad12.csv')
df_hiper_libertad_13 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad13.csv')
df_hiper_libertad_14 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad14.csv')
df_hiper_libertad_15 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad15.csv')
df_hiper_libertad_16 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad16.csv')
df_hiper_libertad_17 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad17.csv')
df_hiper_libertad_18 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad18.csv')
df_hiper_libertad_19 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad19.csv')
df_hiper_libertad_20 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad20.csv')
df_hiper_libertad_21 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad21.csv')
df_hiper_libertad_22 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad22.csv')
df_hiper_libertad_23 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad23.csv')
df_hiper_libertad_24 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad24.csv')
df_hiper_libertad_25 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad25.csv')
df_hiper_libertad_26 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad26.csv')
df_hiper_libertad_27 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad27.csv')
df_hiper_libertad_28 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad28.csv')
df_hiper_libertad_29 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad29.csv')
df_hiper_libertad_30 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad30.csv')
df_hiper_libertad_31 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad31.csv')
df_hiper_libertad_32 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad32.csv')
df_hiper_libertad_33 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad33.csv')
df_hiper_libertad_34 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad34.csv')
df_hiper_libertad_35 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad35.csv')
df_hiper_libertad_36 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad36.csv')
df_hiper_libertad_37 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad37.csv')
df_hiper_libertad_38 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad38.csv')
df_hiper_libertad_39 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad39.csv')
df_hiper_libertad_40 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad40.csv')
df_hiper_libertad_41 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad41.csv')
df_hiper_libertad_42 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad42.csv')
df_hiper_libertad_43 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad43.csv')
df_hiper_libertad_44 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Hiper_Libertad/relevamiento_precios_hiper_libertad44.csv')

# Disco:
df_disco_0 = pd.read_excel('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco.xlsx')
df_disco_1 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco1.csv')
df_disco_2 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco2.csv')
df_disco_3 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco3.csv')
df_disco_4 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco4.csv')
df_disco_5 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco5.csv')
df_disco_6 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco6.csv')
df_disco_7 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco7.csv')
df_disco_8 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco8.csv')
df_disco_9 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco9.csv')
df_disco_10 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco10.csv')
df_disco_11 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco11.csv')
df_disco_12 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco12.csv')
df_disco_13 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco13.csv')
df_disco_14 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco14.csv')
df_disco_15 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco15.csv')
df_disco_16 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco16.csv')
df_disco_17 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco17.csv')
df_disco_18 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco18.csv')
df_disco_19 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco19.csv')
df_disco_20 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco20.csv')
df_disco_21 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco21.csv')
df_disco_22 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco22.csv')
df_disco_23 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco23.csv')
df_disco_24 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco24.csv')
df_disco_25 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco25.csv')
df_disco_26 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco26.csv')
df_disco_27 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco27.csv')
df_disco_28 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco28.csv')
df_disco_29 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco29.csv')
df_disco_30 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco30.csv')
df_disco_31 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco31.csv')
df_disco_32 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco32.csv')
df_disco_33 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco33.csv')
df_disco_34 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco34.csv')
df_disco_35 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco35.csv')
df_disco_36 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco36.csv')
df_disco_37 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco37.csv')
df_disco_38 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco38.csv')
df_disco_39 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco39.csv')
df_disco_40 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco40.csv')
df_disco_41 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco41.csv')
df_disco_42 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco42.csv')
df_disco_43 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco43.csv')
df_disco_44 = pd.read_csv('/content/drive/MyDrive/Web Scrapping - Supermercados/Disco/relevamiento_precios_disco44.csv')

# %%
# Unirlos por super mercado:
df_hiper_libertad = pd.concat([df_hiper_libertad_1, df_hiper_libertad_2,
                               df_hiper_libertad_3, df_hiper_libertad_4,
                               df_hiper_libertad_5, df_hiper_libertad_6,
                               df_hiper_libertad_7, df_hiper_libertad_8,
                               df_hiper_libertad_9, df_hiper_libertad_10,
                               df_hiper_libertad_11, df_hiper_libertad_12
                               , df_hiper_libertad_13 , df_hiper_libertad_14
                               , df_hiper_libertad_15, df_hiper_libertad_16
                               , df_hiper_libertad_17 , df_hiper_libertad_18
                               , df_hiper_libertad_19, df_hiper_libertad_20,
                               df_hiper_libertad_21, df_hiper_libertad_22
                               , df_hiper_libertad_23, df_hiper_libertad_24
                               , df_hiper_libertad_25, df_hiper_libertad_26
                               , df_hiper_libertad_27, df_hiper_libertad_28
                               , df_hiper_libertad_29, df_hiper_libertad_30
                               , df_hiper_libertad_31, df_hiper_libertad_32
                               , df_hiper_libertad_33, df_hiper_libertad_34
                               , df_hiper_libertad_35, df_hiper_libertad_36
                               , df_hiper_libertad_37, df_hiper_libertad_38
                               , df_hiper_libertad_39, df_hiper_libertad_40
                               , df_hiper_libertad_41, df_hiper_libertad_42
                               , df_hiper_libertad_43, df_hiper_libertad_44], ignore_index=True)

df_disco = pd.concat([df_disco_1, df_disco_2, df_disco_3, df_disco_4,
                      df_disco_5, df_disco_6, df_disco_7, df_disco_8,
                      df_disco_9, df_disco_10, df_disco_11, df_disco_12
                      , df_disco_13 , df_disco_14, df_disco_15, df_disco_16
                      , df_disco_17 , df_disco_18, df_disco_19, df_disco_20
                      , df_disco_21, df_disco_22, df_disco_23, df_disco_24
                      , df_disco_25 , df_disco_26, df_disco_27, df_disco_28
                      , df_disco_29, df_disco_30, df_disco_31, df_disco_32
                      , df_disco_33, df_disco_34, df_disco_35, df_disco_36
                      , df_disco_37, df_disco_38, df_disco_39, df_disco_40
                      , df_disco_41, df_disco_43, df_disco_44], ignore_index=True)

# Agregar una columna "supermercado" con el valor correspondiente a cada uno:
df_hiper_libertad['Supermercado'] = 'Hiper Libertad'
df_disco['Supermercado'] = 'Disco'

# %% [markdown]
# ## 2. Exploración Inicial:

# %%
# Verificar encabezados:
df_disco.head()
# Out:
#         fecha   hora                           Nombre Producto Precio  \
# 0  15-04-2025  08:15            Harina 000 Vit X 1 Kg Favorita    900
# 1  15-04-2025  08:15                      Azucar Ledesma X 1kg   1160
# 2  15-04-2025  08:15  Arroz Grano Largo Fino Dos Hermanos 1 Kg   2300
# 3  15-04-2025  08:15          Galletitas Surtido Bagley 400 Gr   2671
# 4  15-04-2025  08:15              Papa Cepillada Granel Por Kg    999
#
#                                                  URL Supermercado
# 0  https://www.disco.com.ar/harina-000-vit-x-1-kg...        Disco
# 1    https://www.disco.com.ar/azucar-ledesma-x-1kg/p        Disco
# 2  https://www.disco.com.ar/arroz-grano-largo-fin...        Disco
# 3  https://www.disco.com.ar/galletitas-surtido-ba...        Disco
# 4  https://www.disco.com.ar/papa-cepillada-granel...        Disco

# %%
df_hiper_libertad.head()
# Out:
#         fecha   hora                           Nombre Producto   Precio  \
# 0  15-04-2025  08:17              HARINA 000 FAVORITA VITA 1KG      800
# 1  15-04-2025  08:17                   ARROZ ALA LGO FINO X1KG     1999
# 2  15-04-2025  08:17                         PAN BAGUETTE X U.      989
# 3  15-04-2025  08:17             PAPA CEPILLADA X 1 KG21 ECOMM  1299, 0
# 4  15-04-2025  08:17  GALLETITAS SANDWICH MEDIATARDE X3 107 G.     1529
#
#                                                  URL    Supermercado
# 0  https://www.hiperlibertad.com.ar/harina-000-fa...  Hiper Libertad
# 1  https://www.hiperlibertad.com.ar/arroz-blanco-...  Hiper Libertad
# 2  https://www.hiperlibertad.com.ar/pan-baguete-x...  Hiper Libertad
# 3  https://www.hiperlibertad.com.ar/papa-cepillad...  Hiper Libertad
# 4  https://www.hiperlibertad.com.ar/galletitas-sa...  Hiper Libertad

# %%
# Dataframe final y unificado:
df_preliminar = pd.concat([df_disco, df_hiper_libertad], ignore_index=True)

# %%
# Se detectó un error en uno de los registros, donde en vez de tener un valor de fecha, figura el valor "Fecha"
df_preliminar['fecha'].unique()
# Out:
# array(['15-04-2025', '16-04-2025', '17-04-2025', '18-04-2025',
#        '19-04-2025', '20-04-2025', '21-04-2025', '22-04-2025',
#        '23-04-2025', '24-04-2025', '25-04-2025', '26-04-2025',
#        '27-04-2025', '28-04-2025', '29-04-2025', '30-04-2025',
#        '01-05-2025', '02-05-2025', '03-05-2025', '04-05-2025',
#        '05-05-2025', '06-05-2025', '08-05-2025', '10-05-2025',
#        '11-05-2025', '12-05-2025', '13-05-2025', '14-05-2025',
#        '15-05-2025', '17-05-2025', '18-05-2025', '19-05-2025',
#        '20-05-2025', '21-05-2025', '22-05-2025', '23-05-2025',
#        '26-05-2025', '27-05-2025', '28-05-2025', '29-05-2025',
#        '30-05-2025', '01-06-2025', '02-06-2025', 'fecha', '31-05-2025'],
#       dtype=object)

# %%
# Filtrar valores que contengan  los nombres de las columnas (esto porque al unir varios dataset, pueden duplicarse los encabezados)
# Filtrar todas las filas donde la columna Fecha no sea igual a 'Fecha'
df_unificado = df_preliminar[df_preliminar["fecha"] != "fecha"]

# %%
# Se solucionó el error
df_unificado['fecha'].unique()
# Out:
# array(['15-04-2025', '16-04-2025', '17-04-2025', '18-04-2025',
#        '19-04-2025', '20-04-2025', '21-04-2025', '22-04-2025',
#        '23-04-2025', '24-04-2025', '25-04-2025', '26-04-2025',
#        '27-04-2025', '28-04-2025', '29-04-2025', '30-04-2025',
#        '01-05-2025', '02-05-2025', '03-05-2025', '04-05-2025',
#        '05-05-2025', '06-05-2025', '08-05-2025', '10-05-2025',
#        '11-05-2025', '12-05-2025', '13-05-2025', '14-05-2025',
#        '15-05-2025', '17-05-2025', '18-05-2025', '19-05-2025',
#        '20-05-2025', '21-05-2025', '22-05-2025', '23-05-2025',
#        '26-05-2025', '27-05-2025', '28-05-2025', '29-05-2025',
#        '30-05-2025', '01-06-2025', '02-06-2025', '31-05-2025'],
#       dtype=object)

# %%
# Previsualizar primeros registros
df_unificado.head()
# Out:
#         fecha   hora                           Nombre Producto Precio  \
# 0  15-04-2025  08:15            Harina 000 Vit X 1 Kg Favorita    900
# 1  15-04-2025  08:15                      Azucar Ledesma X 1kg   1160
# 2  15-04-2025  08:15  Arroz Grano Largo Fino Dos Hermanos 1 Kg   2300
# 3  15-04-2025  08:15          Galletitas Surtido Bagley 400 Gr   2671
# 4  15-04-2025  08:15              Papa Cepillada Granel Por Kg    999
#
#                                                  URL Supermercado
# 0  https://www.disco.com.ar/harina-000-vit-x-1-kg...        Disco
# 1    https://www.disco.com.ar/azucar-ledesma-x-1kg/p        Disco
# 2  https://www.disco.com.ar/arroz-grano-largo-fin...        Disco
# 3  https://www.disco.com.ar/galletitas-surtido-ba...        Disco
# 4  https://www.disco.com.ar/papa-cepillada-granel...        Disco

# %%
# informacion general del dataframe
df_unificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2080 entries, 0 to 2081
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            2080 non-null   object
#  1   hora             2080 non-null   object
#  2   Nombre Producto  1980 non-null   object
#  3   Precio           2080 non-null   object
#  4   URL              2080 non-null   object
#  5   Supermercado     2080 non-null   object
# dtypes: object(6)
# memory usage: 178.3+ KB

# %% [markdown]
# 193 registros en total sin valores nulos

# %%
df_unificado.describe()
# Out:
#              fecha   hora                Nombre Producto         Precio  \
# count         2080   2080                           1980           2080
# unique          44     65                             49            112
# top     08-05-2025  08:18  PAPA CEPILLADA X 1 KG21 ECOMM  No disponible
# freq            72    113                             46            201
#
#                                                       URL Supermercado
# count                                                2080         2080
# unique                                                 49            2
# top     https://www.hiperlibertad.com.ar/yogur-bebible...        Disco
# freq                                                   46         1040

# %% [markdown]
# ## 3. Limpieza de datos

# %%
# Convertir la columna fecha en formato de fecha
df_unificado['fecha'] = pd.to_datetime(df_unificado['fecha'], format = '%d-%m-%Y')
# Out:
# <ipython-input-14-458314cbabcf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unificado['fecha'] = pd.to_datetime(df_unificado['fecha'], format = '%d-%m-%Y')

# %%
# Excluir registros de precios "No disponibles"
df_unificado = df_unificado[df_unificado['Precio'] != "No disponible"]

# %%
# Convertir la columna precio en formato de float:

# hay registros que tienen los precios con coma y un espacio en el valor decimal, lo cual
# impide transformar dicha columna directamente a float, por lo que tengo que realizar
# transformaciones sobre la columna para poder continuar.

# Reemplazar la coma por punto en aquellos registros que contengan "","" y eliminar espacios
for index, value in df_unificado['Precio'].items():
  if ',' in str(value):
    df_unificado.at[index, 'Precio'] = str(value).replace(',', '.').replace(' ', '')

# Convertir a float
df_unificado['Precio'] = df_unificado['Precio'].astype(float)
# Out:
# <ipython-input-16-981f703ac4ac>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_unificado['Precio'] = df_unificado['Precio'].astype(float)

# %%
# seleccionar columnas necesarias para el analisis
df_unificado = df_unificado[['fecha', 'Nombre Producto', 'Precio', 'Supermercado']]

# %%
# Previsualizar primeros registros
df_unificado.head()
# Out:
#        fecha                           Nombre Producto  Precio Supermercado
# 0 2025-04-15            Harina 000 Vit X 1 Kg Favorita   900.0        Disco
# 1 2025-04-15                      Azucar Ledesma X 1kg  1160.0        Disco
# 2 2025-04-15  Arroz Grano Largo Fino Dos Hermanos 1 Kg  2300.0        Disco
# 3 2025-04-15          Galletitas Surtido Bagley 400 Gr  2671.0        Disco
# 4 2025-04-15              Papa Cepillada Granel Por Kg   999.0        Disco

# %%
# informacion general del dataframe
df_unificado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1879 entries, 0 to 2081
# Data columns (total 4 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   fecha            1879 non-null   datetime64[ns]
#  1   Nombre Producto  1879 non-null   object
#  2   Precio           1879 non-null   float64
#  3   Supermercado     1879 non-null   object
# dtypes: datetime64[ns](1), float64(1), object(2)
# memory usage: 137.9+ KB

# %%
df_unificado.describe()
# Out:
#                                fecha        Precio
# count                           1879   1879.000000
# mean   2025-05-07 16:17:52.911123200   2837.497605
# min              2025-04-15 00:00:00    499.500000
# 25%              2025-04-25 00:00:00   1249.000000
# 50%              2025-05-06 00:00:00   2200.000000
# 75%              2025-05-19 00:00:00   3399.000000
# max              2025-06-02 00:00:00  12450.000000
# std                              NaN   2348.850577

# %%
# Multiplicar por dos el valor del precio de la batata en el supermercado
# hiper libertad, ya que  su precio es por medio kilogramos y el precio de disco
# es por 1 kilogramo

for i in range(len(df_unificado)):
  if df_unificado.iloc[i]['Supermercado'] == 'Hiper Libertad':
    if 'batata' in df_unificado.iloc[i]['Nombre Producto'].lower():
      df_unificado.iloc[i, df_unificado.columns.get_loc('Precio')] = (
                df_unificado.iloc[i]['Precio'] * 2
            )

# %%
# Multiplicar por dos el valor del precio de la cebolla en el supermercado
# hiper libertad, ya que  su precio es por medio kilogramos y el precio de disco
# es por 1 kilogramo

for i in range(len(df_unificado)):
  if df_unificado.iloc[i]['Supermercado'] == 'Hiper Libertad':
    if 'cebolla' in df_unificado.iloc[i]['Nombre Producto'].lower():
      df_unificado.iloc[i, df_unificado.columns.get_loc('Precio')] = (
                df_unificado.iloc[i]['Precio'] * 2
            )

# %%
# Multiplicar por dos el valor del precio del pollo en el supermercado
# disco, ya que  su precio es por kilogramos y el precio de hiper libertad
# es por 2 kilogramo

for i in range(len(df_unificado)):
  if df_unificado.iloc[i]['Supermercado'] == 'Disco':
    if 'pollo' in df_unificado.iloc[i]['Nombre Producto'].lower():
      df_unificado.iloc[i, df_unificado.columns.get_loc('Precio')] = (
                df_unificado.iloc[i]['Precio'] * 2.5
            )

# %%
# Estándar de nombres:
# En base al nombre correspondiente se incorpora el nombre estandarizado del producto
# para futuras comparaciones

# Diccionario de elementos de Disco:
productos = ['Galletas de agua','Galletas dulces','Arroz','Harina','Papa',
             'Batata','Azucar','Cebolla','Manzana','Pollo',
             'Salame','Huevo', 'Queso crema', 'Yogur', 'Manteca',
             'Aceite','Gaseosa', 'Cerveza', 'Sal fina','Vinagre', 'Café',
             'Yerba', 'Mayonesa','Pan']

for i in range(len(df_unificado)):
    nombre_actual = df_unificado.iloc[i]['Nombre Producto'].lower()

    #  Condiciones específicas primero
    if 'galletas surtido' in nombre_actual or 'galletitas surtido' in nombre_actual:
        df_unificado.iloc[i, df_unificado.columns.get_loc('Nombre Producto')] = 'Galletas dulces'

    if 'galletitas sandwich mediatarde' in nombre_actual or 'galletitas de agua criollitas' in nombre_actual:
        df_unificado.iloc[i, df_unificado.columns.get_loc('Nombre Producto')] = 'Galletas de agua'

    if 'dulce de leche la serenisima clasico' in nombre_actual or 'dulce leche ilolay fliarx' in nombre_actual:
        df_unificado.iloc[i, df_unificado.columns.get_loc('Nombre Producto')] = 'Dulce de Leche'

    if 'leche entera la serenísima mult vit' in nombre_actual or 'leche entera la serenísima 3' in nombre_actual:
        df_unificado.iloc[i, df_unificado.columns.get_loc('Nombre Producto')] = 'Leche'

    # Reemplazos estándar del listado
    for producto in productos:
        if producto.lower() in nombre_actual:
            df_unificado.iloc[i, df_unificado.columns.get_loc('Nombre Producto')] = producto

# %%
df_unificado.head()
# Out:
#        fecha  Nombre Producto  Precio Supermercado
# 0 2025-04-15           Harina   900.0        Disco
# 1 2025-04-15           Azucar  1160.0        Disco
# 2 2025-04-15            Arroz  2300.0        Disco
# 3 2025-04-15  Galletas dulces  2671.0        Disco
# 4 2025-04-15             Papa   999.0        Disco

# %%
pd.unique(df_unificado['Nombre Producto'])
# Out:
# array(['Harina', 'Azucar', 'Arroz', 'Galletas dulces', 'Papa',
#        'Dulce de Leche', 'Galletas de agua', 'Batata', 'Salame', 'Pollo',
#        'Yogur', 'Aceite', 'Huevo', 'Leche', 'Manteca', 'Gaseosa',
#        'Cerveza', 'Sal fina', 'Yerba', 'Vinagre', 'Queso crema',
#        'Mayonesa', 'Manzana', 'Café', 'Cebolla', 'Pan'], dtype=object)

# %%
# Guardar Dataframe resultante en un archivo excel
df_unificado.to_excel('datos_limpios.xlsx', index=False)

# Descargar a la computadora:
files.download('datos_limpios.xlsx')

# %% [markdown]
# ## 4.  Análisis

# %% [markdown]
# #### a. Evolucion del precio promedio:

# %%
# Evolucion del precio promedio, para observar como varia el precio promedio de los
# productos a lo largo del tiempo

# Agrupar por 'fecha'
evolucion = df_unificado.groupby('fecha')['Precio'].mean().reset_index()

# Ordenar  por fecha
evolucion = evolucion.sort_values('fecha')

# Grafico general
plt.figure(figsize=(10,5))
plt.plot(evolucion['fecha'], evolucion['Precio'], marker='o')
plt.title("Evolución General del precio promedio")
plt.xlabel("Fecha")
plt.ylabel("Precio promedio")
plt.ylim(0, 4000)
plt.grid(True)
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Se detecta una tendencia en baja del promedio de precios **del grupo de productos** analizados en la canasta basica. Dicha caida se produce entre el 17-04-2025 y el 19-04-2025.

# %%
# Grafico de comparacion entre supermercado

# Disco:
disco_evolucion_general =  df_unificado[df_unificado['Supermercado'] == 'Disco']
disco_evolucion = disco_evolucion_general.groupby('fecha')['Precio'].mean().reset_index()

# Hiper Libertad:
hiper_libertad_evolucion_general =  df_unificado[df_unificado['Supermercado'] == 'Hiper Libertad']
hiper_evolucion = hiper_libertad_evolucion_general.groupby('fecha')['Precio'].mean().reset_index()

plt.figure(figsize=(10,5))
plt.plot(disco_evolucion['fecha'], disco_evolucion['Precio'], marker='o', label='Disco', color='red')
plt.plot(hiper_evolucion['fecha'], hiper_evolucion['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.title("Comparacion de la Evolución del precio promedio por supermercado")
plt.xlabel("Fecha")
plt.ylabel("Precio promedio")
plt.ylim(0, 4000)
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %% [markdown]
# **Hiper Libertad** muestra una caída marcada en el precio promedio entre el 15 y el 19 de abril. Comienza con un precio promedio superior a \$2.900 y termina por debajo de \$2.350. La baja más significativa ocurre entre el 17-04-2025 y el 19-04-2025, donde se ve un descenso abrupto.
#
# **Disco**, mantiene una tendencia estable con una leve disminución. Sus precios promedio oscilan cerca de \$2.550 durante todo el período.
#
# Inicialmente, Hiper Libertad tenía precios notablemente más altos que Disco. Hacia el final del período, los precios de Hiper Libertad caen por debajo de Disco, invirtiendo la relación inicial.

# %% [markdown]
# ### b. Comparación de precios entre supermercados

# %%
# Agrupar por producto y supermercado
comparacion = df_unificado.groupby(['Nombre Producto', 'Supermercado'])['Precio'].mean().reset_index()

# Tabla para visualizar mejor el precio promedio por  producto y supermercado
pivot = comparacion.pivot(index='Nombre Producto', columns='Supermercado', values='Precio')
print(pivot)
# Out:
# Supermercado             Disco  Hiper Libertad
# Nombre Producto
# Aceite             4266.418605     4210.000000
# Arroz              2303.571429     1999.000000
# Azucar             1161.860465     1099.000000
# Batata             1149.000000     1832.333333
# Café              12183.333333    10489.000000
# Cebolla             607.333333      999.000000
# Cerveza            3329.069767             NaN
# Dulce de Leche     3374.418605     2380.782609
# Galletas de agua   1522.833333     1529.000000
# Galletas dulces    2698.023256     2034.846154
# Gaseosa            4200.000000             NaN
# Harina              921.428571      832.391304
# Huevo              2450.000000     2205.000000
# Leche              1887.209302     1751.978261
# Manteca            2274.418605     1580.000000
# Manzana            2021.222222     2649.000000
# Mayonesa           1263.255814     1115.538462
# Pan                        NaN      989.000000
# Papa                884.250000     1185.956522
# ...

# %% [markdown]
# Hiper Libertad presenta precios más bajos que Disco en la mayoría de los productos relevados. Esto podría explicar la caída del precio promedio observada en el gráfico anterior, ya que los productos disponibles en ese supermercado tienden a tener un costo menor. Sin embargo, hay excepciones que podrían influir en la percepción general de precios.
#
# * Disco no tiene precios publicados para: Café, Cebolla, Manzana, Pan.
# * Hiper Libertad no tiene precios publicados para: Cerveza, Gaseosa, Mayonesa.

# %% [markdown]
# ## c. Productos con mayor/menor variación de precios

# %%
# Agrupar por producto y calcular medidas de dispersión
variacion = df_unificado.groupby('Nombre Producto')['Precio'].agg(['mean', 'std', 'min', 'max'])

# Calcular el rango de precios
variacion['rango'] = variacion['max'] - variacion['min']

# Calcular el coeficiente de variación
variacion['coef_var'] = variacion['std'] / variacion['mean']

# Ordenar productos por mayor variación (podés usar 'rango' o 'coef_var')
mayor_variacion = variacion.sort_values('coef_var', ascending=False)
menor_variacion = variacion.sort_values('coef_var', ascending=True)

# Ver los 10 productos mas y menos variables:
print(f'Top 10 Productos con mayor variación: \n {mayor_variacion.head(10)} \n')
print(f'\n Top 10 Productos con menor variación:\n  {menor_variacion.head(10)}\n')
# Out:
# Top 10 Productos con mayor variación:
#                          mean          std     min     max   rango  coef_var
# Nombre Producto
# Salame           4810.471910  1533.210151  3082.0  6376.0  3294.0  0.318723
# Batata           1495.923077   368.259942   599.0  1899.0  1300.0  0.246176
# Cebolla           856.575758   192.077951   599.0   999.0   400.0  0.224239
# Manteca          1931.294118   351.655230  1580.0  2400.0   820.0  0.182083
# Dulce de Leche   2860.853933   501.143319  2342.0  3500.0  1158.0  0.175173
# Papa             1045.627907   181.033702   699.0  1299.0   600.0  0.173134
# Sal fina         1366.828571   212.029460  1200.0  1649.0   449.0  0.155125
# Vinagre          1301.011236   193.480648  1115.0  1500.0   385.0  0.148716
# Galletas dulces  2382.609756   339.473040  1990.0  2850.0   860.0  0.142479
# Manzana          2410.267606   328.002307  1899.0  2699.0   800.0  0.136085
#
#
#  Top 10 Productos con menor variación:
# ...

# %% [markdown]
# Los productos con mayor variación de precios son principalmente alimentos frescos como pollo, salame, batata, y leche, que presentan altos valores en desviación estándar, rango y coeficiente de variación.
# Los productos con menor variación presentan precios constantes, como café, cebolla y cerveza, todos con desviación estándar y rango igual a cero.

# %% [markdown]
# ## 5. Visualizaciones

# %% [markdown]
# ## a. Tendencias por producto

# %%
# Agrupar por producto:
df_galletas_agua = df_unificado[df_unificado['Nombre Producto'] == 'Galletas de agua']
df_galletas_agua_disco = df_galletas_agua[df_galletas_agua['Supermercado'] == 'Disco']
df_galletas_agua_hl = df_galletas_agua[df_galletas_agua['Supermercado'] == 'Hiper Libertad']

df_galletas_dulces = df_unificado[df_unificado['Nombre Producto'] == 'Galletas dulces']
df_galletas_dulces_disco = df_galletas_dulces[df_galletas_dulces['Supermercado'] == 'Disco']
df_galletas_dulces_hl = df_galletas_dulces[df_galletas_dulces['Supermercado'] == 'Hiper Libertad']

df_arroz = df_unificado[df_unificado['Nombre Producto'] == 'Arroz']
df_arroz_disco = df_arroz[df_arroz['Supermercado'] == 'Disco']
df_arroz_hl = df_arroz[df_arroz['Supermercado'] == 'Hiper Libertad']

df_harina = df_unificado[df_unificado['Nombre Producto'] == 'Harina']
df_harina_disco = df_harina[df_harina['Supermercado'] == 'Disco']
df_harina_hl = df_harina[df_harina['Supermercado'] == 'Hiper Libertad']

df_papa = df_unificado[df_unificado['Nombre Producto'] == 'Papa']
df_papa_disco = df_papa[df_papa['Supermercado'] == 'Disco']
df_papa_hl = df_papa[df_papa['Supermercado'] == 'Hiper Libertad']

df_batata = df_unificado[df_unificado['Nombre Producto'] == 'Batata']
df_batata_disco = df_batata[df_batata['Supermercado'] == 'Disco']
df_batata_hl = df_batata[df_batata['Supermercado'] == 'Hiper Libertad']

df_azucar = df_unificado[df_unificado['Nombre Producto'] == 'Azucar']
df_azucar_disco = df_azucar[df_azucar['Supermercado'] == 'Disco']
df_azucar_hl = df_azucar[df_azucar['Supermercado'] == 'Hiper Libertad']

df_cebolla = df_unificado[df_unificado['Nombre Producto'] == 'Cebolla']
df_cebolla_disco = df_cebolla[df_cebolla['Supermercado'] == 'Disco']
df_cebolla_hl = df_cebolla[df_cebolla['Supermercado'] == 'Hiper Libertad']

df_manzana = df_unificado[df_unificado['Nombre Producto'] == 'Manzana']
df_manzana_disco = df_manzana[df_manzana['Supermercado'] == 'Disco']
df_manzana_hl = df_manzana[df_manzana['Supermercado'] == 'Hiper Libertad']

df_pollo = df_unificado[df_unificado['Nombre Producto'] == 'Pollo']
df_pollo_disco = df_pollo[df_pollo['Supermercado'] == 'Disco']
df_pollo_hl = df_pollo[df_pollo['Supermercado'] == 'Hiper Libertad']

df_salame = df_unificado[df_unificado['Nombre Producto'] == 'Salame']
df_salame_disco = df_salame[df_salame['Supermercado'] == 'Disco']
df_salame_hl = df_salame[df_salame['Supermercado'] == 'Hiper Libertad']

df_huevo = df_unificado[df_unificado['Nombre Producto'] == 'Huevo']
df_huevo_disco = df_huevo[df_huevo['Supermercado'] == 'Disco']
df_huevo_hl = df_huevo[df_huevo['Supermercado'] == 'Hiper Libertad']

df_leche = df_unificado[df_unificado['Nombre Producto'] == 'Leche']
df_leche_disco = df_leche[df_leche['Supermercado'] == 'Disco']
df_leche_hl = df_leche[df_leche['Supermercado'] == 'Hiper Libertad']

df_queso_crema = df_unificado[df_unificado['Nombre Producto'] == 'Queso crema']
df_queso_crema_disco = df_queso_crema[df_queso_crema['Supermercado'] == 'Disco']
df_queso_crema_hl = df_queso_crema[df_queso_crema['Supermercado'] == 'Hiper Libertad']

df_yogur = df_unificado[df_unificado['Nombre Producto'] == 'Yogur']
df_yogur_disco = df_yogur[df_yogur['Supermercado'] == 'Disco']
df_yogur_hl = df_yogur[df_yogur['Supermercado'] == 'Hiper Libertad']

df_manteca = df_unificado[df_unificado['Nombre Producto'] == 'Manteca']
df_manteca_disco = df_manteca[df_manteca['Supermercado'] == 'Disco']
df_manteca_hl = df_manteca[df_manteca['Supermercado'] == 'Hiper Libertad']

df_aceite = df_unificado[df_unificado['Nombre Producto'] == 'Aceite']
df_aceite_disco = df_aceite[df_aceite['Supermercado'] == 'Disco']
df_aceite_hl = df_aceite[df_aceite['Supermercado'] == 'Hiper Libertad']

df_gaseosa = df_unificado[df_unificado['Nombre Producto'] == 'Gaseosa']
df_gaseosa_disco = df_gaseosa[df_gaseosa['Supermercado'] == 'Disco']
df_gaseosa_hl = df_gaseosa[df_gaseosa['Supermercado'] == 'Hiper Libertad']

df_cerveza = df_unificado[df_unificado['Nombre Producto'] == 'Cerveza']
df_cerveza_disco = df_cerveza [df_cerveza ['Supermercado'] == 'Disco']
df_cerveza_hl = df_cerveza [df_cerveza ['Supermercado'] == 'Hiper Libertad']

df_sal_fina = df_unificado[df_unificado['Nombre Producto'] == 'Sal fina']
df_sal_fina_disco = df_sal_fina[df_sal_fina['Supermercado'] == 'Disco']
df_sal_fina_hl = df_sal_fina[df_sal_fina['Supermercado'] == 'Hiper Libertad']

df_vinagre = df_unificado[df_unificado['Nombre Producto'] == 'Vinagre']
df_vinagre_disco = df_vinagre[df_vinagre['Supermercado'] == 'Disco']
df_vinagre_hl = df_vinagre[df_vinagre['Supermercado'] == 'Hiper Libertad']

df_cafe = df_unificado[df_unificado['Nombre Producto'] == 'Café']
df_cafe_disco = df_cafe[df_cafe['Supermercado'] == 'Disco']
df_cafe_hl = df_cafe[df_cafe['Supermercado'] == 'Hiper Libertad']

df_yerba = df_unificado[df_unificado['Nombre Producto'] == 'Yerba']
df_yerba_disco = df_yerba[df_yerba['Supermercado'] == 'Disco']
df_yerba_hl = df_yerba[df_yerba['Supermercado'] == 'Hiper Libertad']

df_mayonesa = df_unificado[df_unificado['Nombre Producto'] == 'Mayonesa']
df_mayonesa_disco = df_mayonesa[df_mayonesa['Supermercado'] == 'Disco']
df_mayonesa_hl = df_mayonesa[df_mayonesa['Supermercado'] == 'Hiper Libertad']

df_pan = df_unificado[df_unificado['Nombre Producto'] == 'Pan']
df_pan_disco = df_pan[df_pan['Supermercado'] == 'Disco']
df_pan_hl = df_pan[df_pan['Supermercado'] == 'Hiper Libertad']

df_dulce_de_Leche = df_unificado[df_unificado['Nombre Producto'] == 'Pan']
df_dulce_de_Leche_disco =df_dulce_de_Leche[df_dulce_de_Leche['Supermercado'] == 'Disco']
df_dulce_de_Leche_hl = df_dulce_de_Leche[df_dulce_de_Leche['Supermercado'] == 'Hiper Libertad']

# %%
plt.figure(figsize=(20, 100))

#Galletas agua
plt.subplot(13,2,1)
plt.plot(df_galletas_agua_disco['fecha'],df_galletas_agua_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_galletas_agua_hl['fecha'],df_galletas_agua_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Galletas de Agua")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,2)
plt.plot(df_galletas_dulces_disco['fecha'],df_galletas_dulces_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_galletas_dulces_hl['fecha'],df_galletas_dulces_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Galletas Dulces")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,3)
plt.plot(df_arroz_disco['fecha'],df_arroz_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_arroz_hl['fecha'],df_arroz_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Arroz")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,4)
plt.plot(df_harina_disco['fecha'],df_harina_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_harina_hl['fecha'],df_harina_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Harina")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,5)
plt.plot(df_papa_disco['fecha'],df_papa_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_papa_hl['fecha'],df_papa_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Papa")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,6)
plt.plot(df_batata_disco['fecha'],df_batata_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_batata_hl['fecha'],df_batata_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Batata")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,7)
plt.plot(df_azucar_disco['fecha'],df_azucar_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_azucar_hl['fecha'],df_azucar_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Azucar")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,8)
plt.plot(df_cebolla_disco['fecha'],df_cebolla_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_cebolla_hl['fecha'],df_cebolla_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Cebolla")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,9)
plt.plot(df_manzana_disco['fecha'],df_manzana_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_manzana_hl['fecha'],df_manzana_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Manzana")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,10)
plt.plot(df_pollo_disco['fecha'],df_pollo_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_pollo_hl['fecha'],df_pollo_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Pollo")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,11)
plt.plot(df_salame_disco['fecha'],df_salame_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_salame_hl['fecha'],df_salame_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Salame")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,12)
plt.plot(df_huevo_disco['fecha'],df_huevo_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_huevo_hl['fecha'],df_huevo_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Huevos")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,13)
plt.plot(df_leche_disco['fecha'],df_leche_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_leche_hl['fecha'],df_leche_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Leche")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,14)
plt.plot(df_queso_crema_disco['fecha'],df_queso_crema_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_queso_crema_hl['fecha'],df_queso_crema_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Queso Crema")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,15)
plt.plot(df_yogur_disco['fecha'],df_yogur_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_yogur_hl['fecha'],df_yogur_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Yogur")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,16)
plt.plot(df_manteca_disco['fecha'],df_manteca_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_manteca_hl['fecha'],df_manteca_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Manteca")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,17)
plt.plot(df_aceite_disco['fecha'],df_aceite_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_aceite_hl['fecha'],df_aceite_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Aceite")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,18)
plt.plot(df_gaseosa_disco['fecha'],df_gaseosa_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_gaseosa_hl['fecha'],df_gaseosa_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Gaseosa")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,19)
plt.plot(df_cerveza_disco['fecha'],df_cerveza_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_cerveza_hl['fecha'],df_cerveza_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Cerveza")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,20)
plt.plot(df_sal_fina_disco['fecha'],df_sal_fina_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_sal_fina_hl['fecha'],df_sal_fina_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Sal Fina")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,21)
plt.plot(df_vinagre_disco['fecha'],df_vinagre_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_vinagre_hl['fecha'],df_vinagre_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Vinagre")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,22)
plt.plot(df_cafe_disco['fecha'],df_cafe_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_cafe_hl['fecha'],df_cafe_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 14000)
plt.title("Tendencia del precio de Café")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,23)
plt.plot(df_yerba_disco['fecha'],df_yerba_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_yerba_hl['fecha'],df_yerba_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Yerba")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,24)
plt.plot(df_mayonesa_disco['fecha'],df_mayonesa_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_mayonesa_hl['fecha'],df_mayonesa_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Mayonesa")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,25)
plt.plot(df_pan_disco['fecha'],df_pan_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_pan_hl['fecha'],df_pan_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio de Pan")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.subplot(13,2,26)
plt.plot(df_dulce_de_Leche_disco['fecha'],df_dulce_de_Leche_disco['Precio'], marker='o', label='Disco', color='red')
plt.plot(df_dulce_de_Leche_hl['fecha'],df_dulce_de_Leche_hl['Precio'], marker='o', label='Hiper Libertad', color='green')
plt.ylim(0, 9000)
plt.title("Tendencia del precio del Dulce de Leche")
plt.xlabel("Fecha")
plt.ylabel("Precio $")
plt.grid(True)
plt.xticks(rotation=30)
plt.legend()

plt.show()

# %% [markdown]
# Se observa que la mayoría de los productos mantienen precios relativamente estables a lo largo de las fechas analizadas. En general, Hiper Libertad presenta precios más bajos o similares respecto a Disco, aunque hay excepciones donde los precios en Disco son claramente más elevados (como en el caso del pollo, el salame y el queso crema).
# Además, se detectan algunas variaciones escalonadas en productos puntuales como el pollo y el queso crema, donde los precios aumentan progresivamente en Disco, mientras que en Hiper Libertad se mantienen constantes o con menor variabilidad.
# También se nota que varios productos solo están presentes en un supermercado, lo que puede estar relacionado con diferencias en la oferta o en la disponibilidad de productos.
# Finalmente, productos como el café muestran un precio mucho más alto en Hiper Libertad, lo que sugiere posibles diferencias en el tipo de producto o en la marca ofrecida.

# %% [markdown]
# ## b.  Boxplots por supermercado

# %%
plt.figure(figsize=(14, 8))
sns.boxplot(x='Supermercado', y='Precio', data=df_unificado)
plt.title('Distribución de precios por supermercado')
plt.xlabel('Supermercado')
plt.ylabel('Precio')
plt.grid(True, linestyle='--', alpha=0.6)
plt.show()

# %% [markdown]
# Ambos supermercados tienen distribuciones de precios similares en cuanto al rango intercuartílico, aunque Disco presenta una mayor dispersión general, con valores máximos más altos y outliers más extremos.
#
# Esto sugiere que en Disco hay más variabilidad de precios. Hiper Libertad, en cambio, muestra una distribución un poco más contenida, aunque también tiene algunos valores atípicos altos.

# %% [markdown]
# ## c. Heatmaps de variación de precios

# %%
plt.figure(figsize=(12, 8))
sns.heatmap(pivot, cmap='YlOrRd', annot=True, fmt=".1f", linewidths=0.5, linecolor='white')
plt.title('Precio promedio por producto y supermercado')
plt.xlabel('Supermercado')
plt.ylabel('Producto')
plt.tight_layout()
plt.show()

# %% [markdown]
# Se observa que algunos productos presentan variaciones notables en sus precios, destacándose casos como el salame, el queso crema y las galletas dulces, que son considerablemente más caros en Disco. Por otro lado, productos como la manzana, la papa y la sal fina resultan más costosos en Hiper Libertad

# %% [markdown]
# # 📌 Conclusión General del Análisis Exploratorio de Precios en Supermercados (Disco vs. Hiper Libertad)
# El análisis desarrollado permitió observar la evolución de los precios de una canasta básica de productos en dos cadenas de supermercados de Córdoba (Argentina): Disco y Hiper Libertad, a lo largo de varios días consecutivos en abril de 2025. La integración, limpieza y estandarización de los datos fue un paso clave para asegurar la comparabilidad entre productos y formatos.
#
# Entre los principales hallazgos, se identificó que **Hiper Libertad mostró una tendencia más pronunciada a la baja en el precio promedio de productos**, especialmente a partir del 17/04/2025. Esta caída podría estar asociada a estrategias de promociones, descuentos u optimización de surtido. En contraste, **Disco mantuvo precios más estables** a lo largo del período analizado, con variaciones menores.
#
# Desde una perspectiva por producto, se observaron importantes diferencias entre supermercados. Algunos productos como el café, salame y pollo presentaron precios significativamente más altos, generando una gran dispersión. Por otro lado, productos como aceite, arroz y galletitas se mantuvieron con precios estables, lo cual sugiere una política de precios más uniforme en ciertos rubros.
#
# A nivel de dispersión, los boxplots revelaron que Disco tiende a exhibir mayor variabilidad de precios, posiblemente asociada a una mayor diversidad de marcas y calidades ofrecidas, mientras que Hiper Libertad mostró precios más concentrados, aunque con ajustes marcados en los días finales del período observado.
#
# Finalmente, las múltiples visualizaciones por producto ayudaron a detectar tendencias puntuales en alimentos esenciales, como la bajada de precios de lácteos, panificados y productos de almacén en Hiper Libertad, que en algunos casos terminaron con precios incluso menores que los de Disco, invirtiendo la relación inicial.
